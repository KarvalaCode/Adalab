# %%
import random

class Juegos_reunidos:
    
    def __init__(self):
        pass

    # Función para jugar al trívial de geografía
    def trivial(self, aciertos=0, intentos=3): 

        preguntas = {
                            "¿Cuál es el país más pequeño del mundo?": "Vaticano",
                            "¿Cuántos océanos hay en la Tierra? (Escribe la respuesta con un número)": "5",
                            "¿Qué país es el más grande del mundo?": "Rusia",
                            "¿Cuál es la montaña más alta del mundo?": "Everest",
                            "¿Cuál es el río más largo del mundo?": "Nilo",
                            "¿Qué país tiene más habitantes?" : "China",
                            "¿De dónde provienen los osos polares?" :  "Artico",
                            "¿Cuántos mares existen en la Tierra? (Escribe la respuesta con un número)" : "60",
                            "¿Qué río pasa por más países?" : "Danubio",
                            "¿Dónde se encuentra el arrecife de coral más grande?" : "Australia",
                            "¿Cuál es la ciudad más poblada del mundo?" : "Tokio", 
                            "¿Cuál es la ciudad con menos habitantes del mundo?" : "Hum",
                            "¿El desierto más grande del mundo?" : "Sahara",
                            "¿En qué país se hablan más idiomas?" : "Papúa Nueva Guinea",
                            "¿Cuál es la montaña más alta de España?" : "Teide",
                            "¿Cuántos estados forman parte de Estados Unidos? (Escribe la respuesta con un número)" : "50"
                            }  
        
        while aciertos < 5 and intentos > 0:
                        
            pregunta = random.choice(list(preguntas.items()))
            preguntas.pop(pregunta[0])
            intentos = intentos
            respuesta_usuario = input(f"¡Bienvenido! Por favor, responde a la pregunta: {pregunta[0]}. \nTienes {intentos} intentos.").lower()
            
            while intentos > 0:
                
                if respuesta_usuario == pregunta[1].lower():
                    print(f"Enhorabuena has acertado la pregunta: {pregunta[0]}")
                    aciertos += 1
                    break
                    

                else: 
                    intentos -= 1
                    print("Lo siento, la respuesta introducida es incorrecta.")
                    

                    if intentos == 0:
                    
                        print(f"¡Ups! Te has quedado sin intentos. Has perdido, la respuesta a la pregunta {pregunta[0]} es {pregunta[1]} 😨")
                        
                    else:
                        respuesta_usuario = input(f"¡Ánimo!, casi lo tienes, prueba otra vez: {pregunta[0]}\nTienes {intentos} intentos").lower()

        if aciertos == 5:
            print("¡BIEEEEEN! Has ganado.")
            return "Te has pasado el juego 🥰"


    # Función para jugar al piedra, papel o tijera
    def ahorcado(self, errores = 0):
    
        #Lista de palabras.
            palabras = ['Actor', 'Admirador', 'Altitud', 'Amistad', 'Animosidad', 'Arancel', 'Ascensor', 'Asesor', 'Astral', 'Atril', 'Azul', 'Barbaridad', 'Bimestral', 'Binocular', 'Bondad', 'Borrador', 'Brevedad', 'Cabezal', 'Caducidad', 'Calor', 'Cantor', 'Capacidad', 'Capataz', 'Capaz', 'Capital', 'Caridad', 'Cartel', 'Cascabel', 'Cavidad', 'Central', 'Color', 'Comedor', 'Compresor', 'Continental', 'Corcel', 'Corral', 'Costillar', 'Dental', 'Despertador', 'Director', 'Doblez', 'Doctor', 'Dolor', 'Editor', 'Emprendedor', 'Escolar', 'Esencial', 'Febril', 'Feliz', 'Fragilidad', 'Frivolidad', 'General', 'Generosidad', 'Gratitud', 'Hexagonal', 'Hotel', 'Humedad', 'Inmoral', 'Integridad', 'Jocosidad', 'Juventud', 'Latitud', 'Letal', 'Legitimidad', 'Luminosidad', 'Lugar', 'Maldad', 'Mantel', 'Mayor', 'Mejor', 'Mental', 'Moral', 'Mortal', 'Motor', 'Mujer', 'Mural', 'Musical', 'Natural', 'Naturalidad', 'Nariz', 'Narrador', 'Necedad', 'Necesidad', 'Obesidad', 'Papel', 'Pared', 'Pastel', 'Personal', 'Poder', 'Portal', 'Principal', 'Reloj', 'Rectangular', 'Salvador', 'Sanidad', 'Sector', 'Solar', 'Tambor', 'Temblor', 'Terminal', 'Transmisor', 'Ultramar', 'Unidad', 'Universal', 'Universidad', 'Urbanidad', 'Usted', 'Vapor', 'Vecindad', 'Veracidad', 'Veraz', 'Verdad', 'Virtud']

            # Seleccionar una palabra secreta para que el jugador adivinador intente adivinar.        
            palabra_secreta = random.choice(palabras).lower()

            # Se Anicializa el tablero de juego con guiones bajos ("_") para representar las letras no adivinadas.
            palabra_jugador = '-'*len(palabra_secreta)
            lista_palabra_jugador = list(palabra_jugador)
            lista_letras_intentadas = []

            # Se utiliza un bucle `while` para permitir que el jugador adivinador haga múltiples errores hasta que adivine la palabra o se agoten los errores.
            while errores != 10:
                    letra = input('Introduce una letra:').lower()
                    lista_letras_intentadas.append(letra)

                    if letra in palabra_secreta:
                        indice = 0
                        for i in palabra_secreta:
                            if palabra_secreta[indice] == letra:
                                lista_palabra_jugador[indice] = letra
                                indice += 1
                            else:
                                indice +=1      
                        palabra_jugador = "".join(lista_palabra_jugador)

                        print(f"¡Bieeennn! La '{letra}' está en la palabra secreta: {palabra_jugador}.\nLetras intentadas: {lista_letras_intentadas}")
                        
                    else:
                        errores += 1
                        if errores == 1:
                            print("_|_  ")
                        elif errores == 2:
                            print(" |")
                            print(" |")
                            print(" |")
                            print(" |")
                            print("_|_  ")
                        elif errores == 3:
                            print(" ______")
                            print(" |  ")
                            print(" |  ")
                            print(" |  ")
                            print(" |  ")
                            print("_|_ ")
                        elif errores == 4:
                            print(" ______")
                            print(" |    |")
                            print(" |   ")
                            print(" |   ")
                            print(" |   ")
                            print("_|_  ")
                            print(" ______")
                            print(" |    |")
                            print(" |    O")
                            print(" |   ")
                            print(" |   ")
                            print("_|_  ")
                        elif errores == 6:
                            print(" ______")
                            print(" |    |")
                            print(" |    O")
                            print(" |    |")
                            print(" |  ")
                            print("_|_  ")
                        elif errores == 7:
                            print(" ______")
                            print(" |    |")
                            print(" |    O")
                            print(" |   /|")
                            print(" |   ")
                            print("_|_  ")
                        elif errores == 8:
                            print(" ______")
                            print(" |    |")
                            print(" |    O")
                            print(" |   /|\\")
                            print(" |  ")
                            print("_|_  ")
                        elif errores == 9:
                            print(" ______")
                            print(" |    |")
                            print(" |    O")
                            print(" |   /|\\")
                            print(" |   /")
                            print("_|_  ")
                        elif errores == 10:
                            print(" ______")
                            print(" |    |")
                            print(" |    O")
                            print(" |   /|\\")
                            print(" |   / \\")
                            print("_|_  ")
                            print(f"Lo siento, no adivinaste la palabra. La palabra era ¡{palabra_secreta}!")

                        print(f"La letra '{letra}' NO está.\nPalabra a adiviniar: {palabra_jugador}.\nLetras intentadas: {lista_letras_intentadas}")

                    if palabra_jugador == palabra_secreta:
                        print(f'¡Has ganado!\nLa palabra era: {palabra_secreta}.')
                        return f"¡Has adivinado la palabra: {palabra_secreta}."
                    

    # Función para jugar al piedra, papel o tijera
                    
    def piedra_papel_tijera(self, puntos_victoria = 3, puntosjugador_1 = 0, puntos_maquina = 0):
    
        elecciones_jugador_1 = []
        elecciones_maquina = []

        # para repetir las rondas mientras ningún jugador haya ganado
        while puntosjugador_1 < puntos_victoria and puntos_maquina < puntos_victoria:
            opciones = ['piedra', 'papel', 'tijera'] 
            jugador_1 = input("Jugador 1: Escoge 'piedra', 'papel' o 'tijera'.").lower()
            maquina = random.choice(opciones)
            print (f"Jugador 1 ha escogido: {jugador_1}.")
            print (f"La máquina ha escogido: {maquina}.")
            elecciones_jugador_1.append(jugador_1)
            elecciones_maquina.append(maquina)
            
            #empieza el juego
            if jugador_1 not in opciones:
                print('Jugador 1: Recuerda que tienes que escoger entre "piedra", "papel" o "tijera". Vuelve a intentarlo.')
            
            else:
                if jugador_1 == 'piedra' and maquina == 'tijera':
                    print('Jugador 1 ha ganado.')
                    puntosjugador_1 += 1
                elif jugador_1 == 'piedra' and maquina == 'papel':
                    print('La máquina ha ganado.')
                    puntos_maquina += 1
                elif jugador_1 == maquina:
                    print('Habéis empatado.')
                elif jugador_1 == 'papel' and maquina == 'tijera':
                    print('La máquina ha ganado.')
                    puntos_maquina += 1
                elif jugador_1 == 'papel' and maquina == 'piedra':
                    print('Jugador 1 ha ganado.')
                    puntosjugador_1 += 1
                elif jugador_1 == 'tijera' and maquina == 'papel':
                    print('Jugador 1 ha ganado.')
                    puntosjugador_1 += 1
                elif jugador_1 == 'tijera' and maquina == 'piedra':
                    print('La máquina ha ganado.')
                    puntos_maquina += 1      
                print (f"Puntos Jugador 1: {puntosjugador_1}.\nPuntos máquina: {puntos_maquina}.")
                print ("--------------------")
                    
            if puntosjugador_1 == puntos_victoria:
                print(f'Jugador 1: ¡Has ganado! \nEstas han sido tus elecciones: {elecciones_jugador_1}. \nLas elecciones de la máquina: {elecciones_maquina}. \nResultado final {puntosjugador_1} - {puntos_maquina}')
                return f"Ha ganado el jugador 1."
            elif(puntos_maquina == puntos_victoria):
                print(f'Jugador 1: ¡Has perdido! \nEstas han sido tus elecciones: {elecciones_jugador_1}.\nLas elecciones de la máquina: {elecciones_maquina}. \nResultado final {puntos_maquina} - {puntosjugador_1}')
                return f"El jugador 1 ha perdido."

# %%
partida1 = Juegos_reunidos()

# %%
partida1.ahorcado()
# Out:
# ¡Bieeennn! La 'a' está en la palabra secreta: -a---.
# Letras intentadas: ['a']
# _|_
# La letra 't' NO está.
# Palabra a adiviniar: -a---.
# Letras intentadas: ['a', 't']
#  |
#  |
#  |
#  |
# _|_
# La letra 'y' NO está.
# Palabra a adiviniar: -a---.
# Letras intentadas: ['a', 't', 'y']
#  ______
#  |
#  |
#  |
#  |
# _|_
# La letra 'ñ' NO está.
# Palabra a adiviniar: -a---.
# Letras intentadas: ['a', 't', 'y', 'ñ']
#  ______
#  |    |
#  |
#  |
#  |
# _|_
#  ______
#  |    |
#  |    O
#  |
#  |
# _|_
# La letra 'c' NO está.
# Palabra a adiviniar: -a---.
# Letras intentadas: ['a', 't', 'y', 'ñ', 'c']
# La letra 'x' NO está.
# Palabra a adiviniar: -a---.
# Letras intentadas: ['a', 't', 'y', 'ñ', 'c', 'x']
#  ______
#  |    |
#  |    O
#  |    |
#  |
# _|_
# La letra 'c' NO está.
# Palabra a adiviniar: -a---.
# Letras intentadas: ['a', 't', 'y', 'ñ', 'c', 'x', 'c']
#  ______
#  |    |
#  |    O
#  |   /|
#  |
# _|_
# La letra 'g' NO está.
# Palabra a adiviniar: -a---.
# ...
