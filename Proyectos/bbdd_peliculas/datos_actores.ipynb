# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import random


from selenium import webdriver  # Selenium es una herramienta para automatizar la interacción con navegadores web.
from webdriver_manager.chrome import ChromeDriverManager  # ChromeDriverManager gestiona la instalación del controlador de Chrome.
from selenium.webdriver.common.keys import Keys  # Keys es útil para simular eventos de teclado en Selenium.
from selenium.webdriver.support.ui import Select  # Select se utiliza para interactuar con elementos <select> en páginas web.

# Importar librerías para pausar la ejecución
# -----------------------------------------------------------------------
from time import sleep  # Sleep se utiliza para pausar la ejecución del programa por un número de segundos.

# Configuraciones
# -----------------------------------------------------------------------

pd.set_option('display.max_columns', None)  # Establece una opción de Pandas para mostrar todas las columnas de un DataFrame.

# %%
def from_csv_to_lists(csv):
  """
    Esta función toma una archivo csv y los pasa a lista de tuplas.
    
    Args:
    - csv: archivo csv.

    Returns:
    - list(df.itertuples(index=False, name=None)): lisat de tuplas
    """
  #lee el csv y lo pasa  a dataframe
  df = pd.read_csv(csv)
  try:
    df = df.drop('Unnamed: 0', axis=1)
  except:
    pass
  #devuelve lisat de tuplas
  return list(df.itertuples(index=False, name=None))

# %%
# ACTORES únicos:
def actores_unicos(lista_tupla_actores):
    """
    Esta función toma una lista de tuplas de (id pelicula y 10 actores principales de la pelicula) y devuelve una lista de actores únicos.
    
    Args:
    - lista_tupla_actores: lista de tuplas de 10 actores principlaes de una peli (id pelicula, actor1-actor10) depues de pasar por la funcion datos_imdb().

    Returns:
    - set(actores): un ser de todos los actores únicos. 
    """
    actores=[]
    for tupla in lista_tupla_actores:
        for actor in tupla[1:]:
            actores.append(actor)
    return set(actores)

# %%
#Informacion actores
def datos_actores(lista_actores):
    """
    Esta función toma una lista de actores y busca información de cada actor en imdb.

    Args:
    - lista_actores: lista de actores (lista de actores que viene de pasar por la funcion datos_imdb() y actores_unicos()

    Returns:
    - detalles_actores: lista de datos de cada actor en una tupla (nombre actor, año nacimiento, conocido por, que hace, premios oscar)
    """

    driver = webdriver.Chrome()

    detalles_actores = []
    detalles_actor = []

    num = 1
    for actor in lista_actores[:1001]:

        driver.maximize_window()
        driver.get("https://www.imdb.com/")

        sleep(0.5)
        print(f"{num}. {actor}")
        try:
            #Escribe el nombre del actor en el buscador
            driver.find_element("css selector", "#suggestion-search").send_keys(actor, Keys.ENTER)
        except:
            driver.get("https://www.imdb.com/")
            driver.find_element("css selector", "#suggestion-search").send_keys(actor, Keys.ENTER)
        
        sleep(0.5)
        try:
            try:
                try:
                    try:
                        driver.find_element("css selector", '#__next > main > div.ipc-page-content-container.ipc-page-content-container--full.sc-383f2ac5-0.bfcGjo > div.ipc-page-content-container.ipc-page-content-container--center > section > div > div.ipc-page-grid__item.ipc-page-grid__item--span-2 > section:nth-child(3) > div.sc-17bafbdb-2.ffAEHI > ul > li:nth-child(1) > div.ipc-metadata-list-summary-item__c > div > a').click()
                    except:
                        driver.find_element("css selector", 'li.find-name-result:nth-child(1) > div:nth-child(2) > div:nth-child(1) > a:nth-child(1)').click()
                except:
                    driver.find_element("css selector", '.find-name-result > div:nth-child(2) > div:nth-child(1) > a:nth-child(1)').click()
            except:
                driver.find_element("css selector", '#__next > main > div.ipc-page-content-container.ipc-page-content-container--full.sc-872d7ac7-0.fqEQWL > div.ipc-page-content-container.ipc-page-content-container--center > section > div > div.ipc-page-grid__item.ipc-page-grid__item--span-2 > section:nth-child(4) > div.sc-17bafbdb-2.iUyFfD > ul > li:nth-child(1) > div.ipc-metadata-list-summary-item__c > div > a').click()
        except: 
                pass   
        try:     
            try:
                que_hace = driver.find_element("css selector", '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-304f99f6-0.eaRXHu > section > div:nth-child(4) > section > section > div.sc-e226b0e3-3.jJsEuz > div > ul').text
                que_hace = que_hace.split('\n')
            
            except:
                que_hace = driver.find_element("css selector", '.sc-7f1a92f5-4').text
                que_hace = que_hace.split('\n')
        except:
            que_hace = 'No data'  
        print(f"que hace: {que_hace}")
            
        try:
            try:
                try:    
                    try:    
                        try:
                            conocido = driver.find_element("css selector", '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-304f99f6-0.eaRXHu > div > section > div > div.sc-9178d6fe-1.kFxVZc.ipc-page-grid__item.ipc-page-grid__item--span-2 > div.celwidget > section:nth-child(1) > div.sc-a6d4b6c0-0.jGufEe').text
                            conocido = conocido.split('\n')[0::4]
                        except:
                            conocido = driver.find_element("css selector", '.ipc-sub-grid--page-span-2').text
                            conocido = conocido.split('\n')[0::4]
                    except:
                        conocido = driver.find_element("xpath", '/html/body/div[2]/main/div/section[1]/div/section/div/div[1]/div[3]/section[1]/div[2]/div/div[2]').text
                        conocido = conocido.split('\n')[0::4]
                except:
                    conocido = driver.find_element("xpath", '/html/body/div[2]/main/div/section[1]/div/section/div/div[1]/div[4]/section[1]/div[2]/div/div[2]').text
                    conocido = conocido.split('\n')[0::4]
            except:
                conocido = driver.find_element("css selector", '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-304f99f6-0.fSJiHR > div > section > div > div.sc-9178d6fe-1.fqVKQb.ipc-page-grid__item.ipc-page-grid__item--span-2 > div.celwidget > section:nth-child(1) > div.sc-a6d4b6c0-0.bBRhdF > div > div.ipc-sub-grid.ipc-sub-grid--page-span-2.ipc-sub-grid--wraps-at-above-l.ipc-shoveler__grid').text
                conocido = conocido.split('\n')[0::4]                   
                  
        except:
            conocido = 'No data'
        print(f"conocido: {conocido}")

        try:
            try:
                año = driver.find_element("css selector", '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-304f99f6-0.eaRXHu > section > div:nth-child(4) > section > section > div.sc-e226b0e3-4.ecgcFy > div.sc-e226b0e3-6.hfusNC > div.sc-e226b0e3-11.jSQoAO > section > aside > div > span:nth-child(2)').text.split(' ')[-1]
            
            except:
                año = driver.find_element("css selector", 'aside.sc-dec7a8b-0:nth-child(1) > div:nth-child(1) > span:nth-child(2)').text.split(' ')[-1]
        except:
            año = 'No data'
        print(f"año: {año}")    

        try:
            try:
                premios = driver.find_element("css selector", '#__next > main > div > section.ipc-page-background.ipc-page-background--base.sc-304f99f6-0.eaRXHu > div > section > div > div.sc-9178d6fe-1.kFxVZc.ipc-page-grid__item.ipc-page-grid__item--span-2 > section:nth-child(3) > div > ul > li > a.ipc-metadata-list-item__label.ipc-metadata-list-item__label--link').text
                if premios == 'Premios':
                    premios = 'Sin Oscar'
            except:
                premios = driver.find_element("css selector", 'ul.ipc-metadata-list:nth-child(2) > li:nth-child(1) > a:nth-child(1)').text
                if premios == 'Premios':
                    premios = 'Sin Oscar'
        except:
            premios = 'Sin oscar'
        print(f"premios: {premios}")
        #nombre actor, año nacimiento, conocido por, que hace, premios oscar
        detalles_actor = (actor, año, conocido, que_hace, premios)

        detalles_actores.append(detalles_actor)
        num += 1
    return detalles_actores

# %%
#csv de los actores desde las peliculas buscadas en imdb a lista de actores únicos
actores_peliculas_2016_1000 = from_csv_to_lists('actores_peliculas_2016_1000.csv')
lista_actores_imdb_2016_1000 = actores_unicos(actores_peliculas_2016_1000)
lista_actores_imdb_2016_1000 = list(lista_actores_imdb_2016_1000)
lista_actores_imdb_2016_1000

# %%
#busca datos actores, lista de los datos de los actores a df y de df a csv
lista_datos_actores_2016_1000_1000 = datos_actores(lista_actores_imdb_2016_1000)
df_datos_actores_2016_1000_1000 = pd.DataFrame(lista_datos_actores_2016_1000_1000)
df_datos_actores_2016_1000_1000.to_csv('lista_actores_2016_1000_1000.csv', index=False)

df_datos_actores_2016_1000_1000
# Out:
# 1. nan
# que hace: ['Reparto']
# conocido: ['']
# año: 1928
# premios: Ganó 4 premios Primetime Emmy
# 2. Keanu Reeves
# que hace: ['Reparto', 'Producción', 'Equipos adicionales']
# conocido: ['']
# año: 1964
# premios: Sin Oscar
# 3. Justin Park
# que hace: ['Especialistas', 'Reparto']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 4. Graham Deller
# que hace: ['Reparto']
# conocido: ['Friendship Love and Loyalty', 'Taxi Driver', '2016']
# año: No data
# premios: Sin oscar
# 5. Deborah Strang
# que hace: ['Reparto']
# conocido: ['']
# año: 1950
# premios: Sin Oscar
# 6. Justin Gaston
# que hace: ['Reparto', 'Banda sonora']
# conocido: ['']
# año: 1988
# premios: Sin oscar
# 7. Leyla Azizi
# que hace: ['Reparto']
# conocido: ['Be Vaghte Sham', '5,3', "Ali's mother", '2018', 'Art Is Dead', '7,0', 'Louise(as Laila Azizi)', '2018', 'Sargije', 'Reparto', '2008', 'Tanha Delkhoshi-ye Man', 'Reparto', '2010']
# año: No data
# premios: Sin oscar
# 8. Aref Khushal
# que hace: ['Reparto']
# conocido: ['Faces and Mirrors', 'Joe', '2016']
# año: No data
# premios: Sin oscar
# 9. Shree Shruthi
# que hace: ['Reparto']
# conocido: ['Neeyillathe', 'Reparto', 'Raj Bahaddur', 'Reparto', '2016']
# año: No data
# premios: Sin oscar
# 10. Kharaj Mukherjee
# que hace: ['Reparto', 'Música', 'Guion']
# conocido: ['']
# año: 1963
# premios: Sin Oscar
# 11. Vasanth
# que hace: ['Dirección', 'Guion', 'Producción']
# conocido: ['Sivaranjiniyum Innum Sila Pengalum', '7,0', 'Dirección', '2019', 'Aasai', '7,5', 'Dirección', '1995', 'Keladi Kanmani', '7,4', 'Dirección', '1990', 'Nerukku Ner', '7,5', 'Dirección', '1997']
# año: 1963
# premios: Sin Oscar
# 12. Vincent Kartheiser
# que hace: ['Reparto']
# conocido: ['']
# año: 1979
# premios: Sin Oscar
# 13. Monique Green
# que hace: ['Reparto']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 14. Spencer Bogaert
# que hace: ['Reparto', 'Dirección de fotografía y cámara', 'Dirección']
# conocido: ['']
# año: No data
# premios: Sin Oscar
# 15. Yuna Shin
# que hace: ['Reparto']
# conocido: ['']
# año: No data
# premios: Sin Oscar
# 16. Jaswant Daman
# que hace: ['Reparto']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 17. Lightfield Lewis
# que hace: ['Reparto', 'Dirección', 'Guion']
# conocido: ['']
# año: 1970
# premios: Sin oscar
# 18. Vanessa Leigh
# que hace: ['Reparto', 'Maquillaje', 'Arte']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 19. Tracy Phillips
# que hace: ['Reparto', 'Equipos adicionales']
# conocido: ['']
# año: 1974
# premios: Sin oscar
# 20. Rob Porter
# que hace: ['Equipos adicionales']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 21. B.C. Patil
# que hace: ['Reparto', 'Dirección', 'Guion']
# conocido: ['Salute', 'Reparto', '2009', 'Hatthoora Odeya', 'Reparto', '2002', 'Shivappa Nayaka', 'Reparto', '2001', 'Lankesha', 'Reparto', '2001']
# año: No data
# premios: Sin oscar
# 22. Kevin Kilner
# que hace: ['Reparto']
# conocido: ['']
# año: 1958
# premios: Sin oscar
# 23. Eve Mauro
# que hace: ['Reparto', 'Producción', 'Guion']
# conocido: ['']
# año: diciembre
# premios: Sin Oscar
# 24. Alden Ehrenreich
# que hace: ['Reparto', 'Dirección', 'Guion']
# conocido: ['']
# año: 1989
# premios: Sin Oscar
# 25. Esma Daniel
# que hace: ['Reparto', 'Dirección', 'Guion']
# conocido: ['Zaiton: Ceritaku', '8,3', 'Dirección', '2012', 'Santau', '6,0', 'Halim', '2009', 'XX Ray', '7,4', 'Kawan Karim', '1992', 'Juang', '6,9', 'Nadma Senior Officer', '2022']
# año: 1969
# premios: Sin Oscar
# 26. Harish Rai
# que hace: ['Reparto']
# conocido: ['K.G.F: Chapter 1', '8,2', 'Khasim', '2018', 'K.G.F: Chapter 2', '8,3', 'Khasim', '2022', 'Om', '9,0', 'Roy', '1995', 'Meendum Oru Kadhal Kadhai', '5,6', 'Manoj', '2016']
# año: No data
# premios: Sin oscar
# 27. Claudio Castañeda
# que hace: ['Reparto']
# conocido: ['Cierre a Blancas', 'Romualdo', '2014']
# año: No data
# premios: Sin oscar
# 28. Ashley Judd
# que hace: ['Reparto', 'Producción', 'Dirección']
# conocido: ['']
# año: 1968
# premios: Nominado para 2 premios Primetime Emmy
# 29. Marko Nisevich
# que hace: ['Reparto', 'Producción']
# conocido: ['Yugoslavia: The Avoidable War', '6,8', 'Producción', '1999', 'Morality', '8,3', 'Homer Cobb', '2016']
# año: No data
# premios: Sin oscar
# 30. Ralph Kasarian
# que hace: ['Reparto']
# conocido: ['Fairlane Road', '4,3', 'Sancho', '2016']
# año: No data
# premios: Sin oscar
# 31. Georgia Cook
# que hace: ['Reparto']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 32. Vanda Petrelli
# que hace: No data
# conocido: ["Che cos'è un manrico", 'Self', '2016']
# año: No data
# premios: Sin oscar
# 33. Seema Singh
# que hace: ['Reparto', 'Dirección de producción', 'Equipos adicionales']
# conocido: ['Hum Do Anjaane', '4,1', 'Item girl', '2011', 'Himmatwala', 'Item girl', '2012', 'Raja Babu', '6,6', 'Girl in Car', '2015', 'Diler', 'Item girl', '2013']
# año: No data
# premios: Sin oscar
# 34. Ylenia Cuzzupé
# que hace: ['Reparto']
# conocido: ['Malamuri', 'Controfigura Carmela', '2016']
# año: No data
# premios: Sin oscar
# 35. Rebecca Barras
# que hace: ['Reparto', 'Producción']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 36. Lloyd Kaufman
# que hace: ['Reparto', 'Producción', 'Dirección']
# conocido: ['']
# año: 1945
# premios: Sin Oscar
# 37. Julian Rhind-Tutt
# que hace: ['Reparto', 'Producción', 'Equipos adicionales']
# conocido: ['']
# año: 1968
# premios: Sin oscar
# 38. Carlos Valencia
# que hace: ['Dirección', 'Guion', 'Producción']
# conocido: ['The Chicken Party', '5,1', 'Dirección', '2018', 'The Ktown Shorts', 'Miniserie de TV', 'Dirección', '2020 • 3 episodios', 'The Midnight Screening', 'Dirección', '2012', 'Team Investigating the Supernatural', 'Serie de TV', 'Dirección', '2013']
# año: No data
# premios: Sin Oscar
# 39. Ann Heavey
# que hace: No data
# conocido: ['Pow Wow', '7,1', 'Self', '2016']
# año: No data
# premios: Sin oscar
# 40. Kaili Thorne
# que hace: ['Reparto', 'Guion', 'Producción']
# conocido: ['']
# año: 1992
# premios: Sin oscar
# 41. Mari C. Blackwell
# que hace: ['Reparto']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 42. Ruhua Xianyu
# que hace: ['Reparto']
# conocido: ['Deliverers', 'Wenling', '2016']
# año: No data
# premios: Sin oscar
# 43. Peter Chavez
# que hace: ['Reparto', 'Dirección', 'Dirección de fotografía y cámara']
# conocido: ['The Girl Code', 'Corto', 'Limo Driver', '2014', 'Élan Vital', 'Lounge Bassist', '2016', 'Labels and Other Lame Excuses', 'Corto', 'Dirección de fotografía y cámara', '2015']
# año: No data
# premios: Sin oscar
# 44. Sam Obiagi
# que hace: ['Reparto']
# conocido: ['Echoes of Love', 'Amucheazi', '2016', 'Circle of Fire', 'King Nwokike(as Sam Obiagu)', '2017', 'Heart Ripper', 'Reparto', '2019', 'Agunnia the Warrior', 'Reparto(as Sam Obiago)', '2021']
# año: No data
# premios: Sin oscar
# 45. Kholood Abdo Hintzman
# que hace: No data
# conocido: ['The Lost City of Cecil B. DeMille', '7,6', 'Archaeologist', '2016']
# año: No data
# premios: Sin oscar
# 46. Bogdan Diklic
# que hace: ['Reparto']
# conocido: ['']
# año: 1953
# premios: Sin Oscar
# 47. Jeff Gladstone
# que hace: ['Reparto', 'Producción', 'Composición']
# conocido: ['']
# año: No data
# premios: Sin Oscar
# 48. Angelina Grassi
# que hace: ['Reparto']
# conocido: ['Stockholm', '5,1', 'Nena del Rio 1', '2016']
# año: No data
# premios: Sin oscar
# 49. Karthik Samaga
# que hace: ['Reparto']
# conocido: ['Kalantaka', 'Reparto', '2021', 'Dynamic', 'Reparto', '2016', 'Muddulakshmi', '3,6', 'Serie de TV', 'Reparto', '2021–2023 • 668 episodios']
# año: No data
# premios: Sin oscar
# 50. Aalvin Amala Prasanna
# que hace: ['Dirección', 'Reparto']
# conocido: ['Anbudan Anbarasi', 'Dirección', '2016']
# año: No data
# premios: Sin oscar
# 51. Julia Ragnarsson
# que hace: ['Reparto']
# conocido: ['']
# año: 1992
# premios: Sin Oscar
# 52. D. Yoga Raj
# que hace: ['Guion', 'Dirección', 'Reparto']
# conocido: ['Revenge', 'Guion', '2019', 'Tilineeru', 'Guion', '2016']
# año: No data
# premios: Sin oscar
# 53. Patricia Velasquez
# que hace: ['Reparto', 'Producción']
# conocido: ['']
# año: 1971
# premios: Sin Oscar
# 54. Deborah Twiss
# que hace: ['Reparto', 'Producción', 'Dirección']
# conocido: ['']
# año: diciembre
# premios: Sin Oscar
# 55. Luke Grande
# que hace: ['Reparto', 'Composición', 'Banda sonora']
# conocido: ['De repente, la película', '7,7', 'Marvin Blutowski', '2011', 'Faun Moon', 'Corto', 'The Faun', '2013', 'Tomasa Tequiero', '9,0', 'Serie de TV', 'Banda sonora("La Negra Tomasa")', '2009', 'El Fantasma de Elena', '6,8', 'Serie de TV', 'Barman', '2010 • 1 episodio']
# año: No data
# premios: Sin Oscar
# 56. Jay Reum
# que hace: ['Reparto', 'Sonido']
# conocido: ['']
# año: No data
# premios: Sin oscar
# 57. Antonio Mayans
# que hace: ['Reparto', 'Dirección de producción', 'Guion']
# conocido: ['']
# año: 1939
# premios: Sin Oscar
# 58. Virginia de Ferrante
# que hace: ['Casting', 'Dirección de la segunda unidad o asistencia a dirección', 'Dirección']
# conocido: ['El lobo detrás de la puerta', '7,4', 'Casting', '2013', 'Nina', 'Corto', 'Dirección o asistencia de la segunda unidad', '2013', 'Inquietação', 'Dirección', '2016', 'Até que a Sorte nos Separe', '5,5', 'Casting', '2012']
# año: No data
# premios: Sin oscar
