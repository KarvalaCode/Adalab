# %%
# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# Visualización
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# Evaluar linealidad de las relaciones entre las variables
# y la distribución de las variables
# ------------------------------------------------------------------------------
import scipy.stats as stats

# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# Gestión de los warnings
# -----------------------------------------------------------------------
import warnings
warnings.filterwarnings("ignore")

# %%
# establece el estilo del fondo de las gráficas como "whitegrid". Las gráficas tendrán un fondo blanco con líneas de cuadrícula horizontales y verticales.
sns.set_style("dark")
# cambiará el esquema de colores predeterminado de Seaborn a uno más oscuro, adecuado para gráficas con fondos claros.
sns.set_theme(style="dark")
# establece el estilo en Solarize_Lihgt2.
plt.style.use('dark_background')

# %%
df=pd.read_csv("../data/datos_empleados.csv", index_col=0)

# %%
df['job_satisfaction']>=3
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4       False
#         ...
# 1609     True
# 1610    False
# 1611     True
# 1612     True
# 1613     True
# Name: job_satisfaction, Length: 1510, dtype: bool

# %%
df['grupo'] = np.where(df['job_satisfaction']>=3, 'control', 'variante')

# %%
df.head()
# Out:
#    employee_number  age attrition business_travel              department  \
# 0                1   51        No     desconocido             desconocido
# 1                2   52        No     desconocido             desconocido
# 2                3   42        No   travel_rarely   research_development
# 3                4   47        No   travel_rarely             desconocido
# 4                5   46        No     desconocido             desconocido
#
#       education   education_field  environment_satisfaction  gender  \
# 0  bachillerato       desconocido                         1    male
# 1   universidad     life_sciences                         3    male
# 2            fp  technical_degree                         3    male
# 3   universidad           medical                         1  female
# 4  bachillerato  technical_degree                         1  female
#
#    job_involvement  job_level           job_role  job_satisfaction  \
# 0                3          5  research_director                 3
# 1                2          5            manager                 3
# 2                3          5            manager                 4
# 3                3          4  research_director                 3
# 4                4          4    sales_executive                 1
#
#   marital_status  monthly_rate  num_companies_worked     overtime  \
# 0    desconocido          6462                     7           No
# 1    desconocido          5678                     0  desconocido
# 2        married          4933                     1           No
# 3        married         26703                     3  desconocido
# 4       divorced          7739                     2           No
#
#    percent_salary_hike  performance_rating  relationship_satisfaction  \
# 0                   13                 3.0                          3
# 1                   14                 3.0                          1
# 2                   11                 3.0                          4
# 3                   19                 3.0                          2
# 4                   12                 3.0                          4
#
#    stock_option_level  training_times_last_year  work_life_balance  \
# 0                   0                         5                  3
# 1                   1                         5                  3
# 2                   0                         3                  3
# 3                   2                         2                  3
# 4                   1                         5                  3
#
#    years_at_company  years_since_last_promotion  years_with_curr_manager  \
# 0                20                          15                       15
# 1                33                          11                        9
# 2                22                          11                       15
# 3                20                           5                        6
# 4                19                           2                        8
#
#    date_birth remote_work  hourly_rate  daily_rate  distance_from_home  \
# 0        1972         yes           51       684.0                 6.0
# 1        1971         yes           65       699.0                 1.0
# 2        1981         yes           58       532.0                 4.0
# 3        1976          no           82       359.0                 2.0
# 4        1977          no           45      1319.0                 3.0
#
#    monthly_income  total_working_years     grupo
# 0         19537.0                    6   control
# 1         19999.0                   34   control
# 2         19232.0                   22   control
# 3         17169.0                    5   control
# 4          5361.8                    6  variante

# %%
df['grupo']
# Out:
# 0        control
# 1        control
# 2        control
# 3        control
# 4       variante
#           ...
# 1609     control
# 1610    variante
# 1611     control
# 1612     control
# 1613     control
# Name: grupo, Length: 1510, dtype: object

# %%
df['grupo'].unique()
# Out:
# array(['control', 'variante'], dtype=object)

# %%
df.columns
# Out:
# Index(['employee_number', 'age', 'attrition', 'business_travel', 'department',
#        'education', 'education_field', 'environment_satisfaction', 'gender',
#        'job_involvement', 'job_level', 'job_role', 'job_satisfaction',
#        'marital_status', 'monthly_rate', 'num_companies_worked', 'overtime',
#        'percent_salary_hike', 'performance_rating',
#        'relationship_satisfaction', 'stock_option_level',
#        'training_times_last_year', 'work_life_balance', 'years_at_company',
#        'years_since_last_promotion', 'years_with_curr_manager', 'date_birth',
#        'remote_work', 'hourly_rate', 'daily_rate', 'distance_from_home',
#        'monthly_income', 'total_working_years', 'grupo'],
#       dtype='object')

# %%
control= df["grupo"]=="control"

# %%
variante= df["grupo"]=="variante"

# %%
si=df["attrition"]=="Yes"
no=df["attrition"]=="No"

# %%
df["attrition"].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df[control&si]
# Out:
#       employee_number  age attrition    business_travel  \
# 13                 14   41       Yes      travel_rarely
# 26                 27   52       Yes        desconocido
# 81                 82   58       Yes      travel_rarely
# 132               128   33       Yes      travel_rarely
# 163               159   35       Yes        desconocido
# ...               ...  ...       ...                ...
# 1569             1466   26       Yes  travel_frequently
# 1600             1497   55       Yes        desconocido
# 1602             1499   26       Yes        desconocido
# 1604             1501   41       Yes        desconocido
# 1609             1506   36       Yes      travel_rarely
#
#                   department     education education_field  \
# 13               desconocido  bachillerato     desconocido
# 26               desconocido           eso     desconocido
# 81               desconocido   universidad         medical
# 132              desconocido   universidad           other
# 163              desconocido   universidad           other
# ...                      ...           ...             ...
# 1569             desconocido   universidad   life_sciences
# 1600             desconocido           eso         medical
# 1602             desconocido            fp         medical
# 1604   research_development    universidad   life_sciences
# 1609             desconocido           eso   life_sciences
#
#       environment_satisfaction  gender  job_involvement  job_level  \
# 13                           2  female                3          5
# 26                           1  female                1          5
# 81                           4  female                3          3
# 132                          4    male                3          1
# 163                          4    male                3          2
# ...                        ...     ...              ...        ...
# 1569                         2  female                3          1
# 1600                         3    male                3          2
# 1602                         3  female                2          1
# 1604                         2  female                1          1
# 1609                         3    male                2          3
#
#                        job_role  job_satisfaction marital_status  \
# 13            research_director                 3        married
# 26                      manager                 4        married
# 81    healthcare_representative                 4        married
# 132          research_scientist                 4         single
# 163             sales_executive                 4    desconocido
# ...                         ...               ...            ...
# 1569            human_resources                 3    desconocido
# 1600            sales_executive                 4         single
# 1602         research_scientist                 3        married
# 1604      laboratory_technician                 4       divorced
# 1609            sales_executive                 4        married
#
#       monthly_rate  num_companies_worked     overtime  percent_salary_hike  \
# 13           16280                     1           No                   12
# 26           25846                     1           No                   15
# 81            3465                     1  desconocido                   12
# 132           5207                     1  desconocido                   13
# 163          10414                     3  desconocido                   24
# ...            ...                   ...          ...                  ...
# 1569         22808                     0          Yes                   11
# 1600         21519                     4  desconocido                   16
# 1602         20898                     1  desconocido                   14
# 1604         17725                     4          Yes                   13
# 1609          5518                     1  desconocido                   11
#
#       performance_rating  relationship_satisfaction  stock_option_level  \
# 13                   3.0                          4                   0
# 26                   3.0                          4                   1
# 81                   3.0                          4                   1
# 132                  3.0                          3                   0
# 163                  4.0                          1                   0
# ...                  ...                        ...                 ...
# 1569                 3.0                          2                   1
# 1600                 3.0                          3                   0
# 1602                 3.0                          1                   1
# 1604                 3.0                          3                   1
# 1609                 3.0                          1                   1
#
#       training_times_last_year  work_life_balance  years_at_company  \
# 13                           0                  3                22
# 26                           3                  3                32
# 81                           3                  2                40
# 132                          2                  2                10
# 163                          2                  4                11
# ...                        ...                ...               ...
# 1569                         2                  3                 7
# 1600                         3                  2                 9
# 1602                         2                  3                 8
# 1604                         1                  2                 7
# 1609                         6                  3                16
#
#       years_since_last_promotion  years_with_curr_manager  date_birth  \
# 13                            15                        8        1982
# 26                             6                        9        1971
# 81                            15                        6        1965
# 132                            7                        8        1990
# 163                            6                        7        1988
# ...                          ...                      ...         ...
# 1569                           1                        0        1997
# 1600                           7                        3        1968
# 1602                           1                        7        1997
# 1604                           1                        0        1982
# 1609                           3                        7        1987
#
#      remote_work  hourly_rate  daily_rate  distance_from_home  monthly_income  \
# 13            no           49      1360.0                12.0         19545.0
# 26           yes           57       266.0                 2.0         19845.0
# 81           yes           94       147.0                23.0          9655.4
# 132           no           63       527.0                 1.0          6622.0
# 163          yes           36       880.0                12.0          4440.2
# ...          ...          ...         ...                 ...             ...
# 1569         yes           58       426.0                17.0          2741.0
# 1600         yes           37       436.0                 2.0          7416.2
# 1602         yes           88       779.4                 5.0          2366.0
# 1604         yes           54      1085.0                 2.0          6479.4
# 1609          no           51       530.0                 3.0         10325.0
#
#       total_working_years    grupo
# 13                      8  control
# 26                     33  control
# 81                     40  control
# 132                    10  control
# 163                    13  control
# ...                   ...      ...
# 1569                    8  control
# 1600                   10  control
# 1602                    8  control
# 1604                    9  control
# 1609                   11  control
#
# [127 rows x 34 columns]

# %%
df
# Out:
#       employee_number  age attrition business_travel              department  \
# 0                   1   51        No     desconocido             desconocido
# 1                   2   52        No     desconocido             desconocido
# 2                   3   42        No   travel_rarely   research_development
# 3                   4   47        No   travel_rarely             desconocido
# 4                   5   46        No     desconocido             desconocido
# ...               ...  ...       ...             ...                     ...
# 1609             1506   36       Yes   travel_rarely             desconocido
# 1610             1507   45        No      non_travel             desconocido
# 1611             1508   39        No   travel_rarely             desconocido
# 1612             1509   36        No      non_travel             desconocido
# 1613             1510   46        No     desconocido             desconocido
#
#          education   education_field  environment_satisfaction  gender  \
# 0     bachillerato       desconocido                         1    male
# 1      universidad     life_sciences                         3    male
# 2               fp  technical_degree                         3    male
# 3      universidad           medical                         1  female
# 4     bachillerato  technical_degree                         1  female
# ...            ...               ...                       ...     ...
# 1609           eso     life_sciences                         3    male
# 1610            fp       desconocido                         3    male
# 1611     doctorado       desconocido                         1    male
# 1612   universidad  technical_degree                         1    male
# 1613            fp           medical                         4    male
#
#       job_involvement  job_level                job_role  job_satisfaction  \
# 0                   3          5       research_director                 3
# 1                   2          5                 manager                 3
# 2                   3          5                 manager                 4
# 3                   3          4       research_director                 3
# 4                   4          4         sales_executive                 1
# ...               ...        ...                     ...               ...
# 1609                2          3         sales_executive                 4
# 1610                3          2   laboratory_technician                 2
# 1611                4          3         sales_executive                 3
# 1612                3          2         sales_executive                 4
# 1613                3          3  manufacturing_director                 3
#
#      marital_status  monthly_rate  num_companies_worked     overtime  \
# 0       desconocido          6462                     7           No
# 1       desconocido          5678                     0  desconocido
# 2           married          4933                     1           No
# 3           married         26703                     3  desconocido
# 4          divorced          7739                     2           No
# ...             ...           ...                   ...          ...
# 1609        married          5518                     1  desconocido
# 1610    desconocido         23163                     1  desconocido
# 1611         single          2560                     0           No
# 1612       divorced         25952                     4           No
# 1613    desconocido         24208                     6  desconocido
#
#       percent_salary_hike  performance_rating  relationship_satisfaction  \
# 0                      13                 3.0                          3
# 1                      14                 3.0                          1
# 2                      11                 3.0                          4
# 3                      19                 3.0                          2
# 4                      12                 3.0                          4
# ...                   ...                 ...                        ...
# 1609                   11                 3.0                          1
# 1610                   12                 3.0                          2
# 1611                   18                 3.0                          4
# 1612                   13                 3.0                          4
# 1613                   13                 3.0                          2
#
#       stock_option_level  training_times_last_year  work_life_balance  \
# 0                      0                         5                  3
# 1                      1                         5                  3
# 2                      0                         3                  3
# 3                      2                         2                  3
# 4                      1                         5                  3
# ...                  ...                       ...                ...
# 1609                   1                         6                  3
# 1610                   0                         5                  2
# 1611                   0                         3                  3
# 1612                   2                         3                  3
# 1613                   1                         3                  3
#
#       years_at_company  years_since_last_promotion  years_with_curr_manager  \
# 0                   20                          15                       15
# 1                   33                          11                        9
# 2                   22                          11                       15
# 3                   20                           5                        6
# 4                   19                           2                        8
# ...                ...                         ...                      ...
# 1609                16                           3                        7
# 1610                 9                           0                        8
# 1611                 8                           0                        7
# 1612                 7                           0                        7
# 1613                 8                           0                        7
#
#       date_birth remote_work  hourly_rate  daily_rate  distance_from_home  \
# 0           1972         yes           51       684.0                 6.0
# 1           1971         yes           65       699.0                 1.0
# 2           1981         yes           58       532.0                 4.0
# 3           1976          no           82       359.0                 2.0
# 4           1977          no           45      1319.0                 3.0
# ...          ...         ...          ...         ...                 ...
# 1609        1987          no           51       530.0                 3.0
# 1610        1978         yes           57       805.0                 4.0
# 1611        1984         yes           41       903.0                10.6
# 1612        1987         yes           84      1229.0                 8.0
# 1613        1977          no           75       566.0                 7.0
#
#       monthly_income  total_working_years     grupo
# 0            19537.0                    6   control
# 1            19999.0                   34   control
# 2            19232.0                   22   control
# 3            17169.0                    5   control
# 4             5361.8                    6  variante
# ...              ...                  ...       ...
# 1609         10325.0                   11   control
# 1610          4447.0                    8  variante
# 1611          7159.4                    9   control
# 1612          5308.8                   12   control
# 1613         10845.0                    9   control
#
# [1510 rows x 34 columns]

# %%
control_si=df[control&si].count()/df[control].count()*100
control_si
contentos_fuera = 13.73 
86.27-13.73

diferencia_contentaos = 75.54
# Out:
# 72.53999999999999

# %%
control_no=df[control&no].count()/df[control].count()*100
control_no
contentos_dentro = 86.27

# %%
df[no]
# Out:
#       employee_number  age attrition business_travel              department  \
# 0                   1   51        No     desconocido             desconocido
# 1                   2   52        No     desconocido             desconocido
# 2                   3   42        No   travel_rarely   research_development
# 3                   4   47        No   travel_rarely             desconocido
# 4                   5   46        No     desconocido             desconocido
# ...               ...  ...       ...             ...                     ...
# 1608             1505   32        No     desconocido             desconocido
# 1610             1507   45        No      non_travel             desconocido
# 1611             1508   39        No   travel_rarely             desconocido
# 1612             1509   36        No      non_travel             desconocido
# 1613             1510   46        No     desconocido             desconocido
#
#          education   education_field  environment_satisfaction  gender  \
# 0     bachillerato       desconocido                         1    male
# 1      universidad     life_sciences                         3    male
# 2               fp  technical_degree                         3    male
# 3      universidad           medical                         1  female
# 4     bachillerato  technical_degree                         1  female
# ...            ...               ...                       ...     ...
# 1608   universidad           medical                         3  female
# 1610            fp       desconocido                         3    male
# 1611     doctorado       desconocido                         1    male
# 1612   universidad  technical_degree                         1    male
# 1613            fp           medical                         4    male
#
#       job_involvement  job_level                job_role  job_satisfaction  \
# 0                   3          5       research_director                 3
# 1                   2          5                 manager                 3
# 2                   3          5                 manager                 4
# 3                   3          4       research_director                 3
# 4                   4          4         sales_executive                 1
# ...               ...        ...                     ...               ...
# 1608                3          2  manufacturing_director                 1
# 1610                3          2   laboratory_technician                 2
# 1611                4          3         sales_executive                 3
# 1612                3          2         sales_executive                 4
# 1613                3          3  manufacturing_director                 3
#
#      marital_status  monthly_rate  num_companies_worked     overtime  \
# 0       desconocido          6462                     7           No
# 1       desconocido          5678                     0  desconocido
# 2           married          4933                     1           No
# 3           married         26703                     3  desconocido
# 4          divorced          7739                     2           No
# ...             ...           ...                   ...          ...
# 1608        married         13554                     1  desconocido
# 1610    desconocido         23163                     1  desconocido
# 1611         single          2560                     0           No
# 1612       divorced         25952                     4           No
# 1613    desconocido         24208                     6  desconocido
#
#       percent_salary_hike  performance_rating  relationship_satisfaction  \
# 0                      13                 3.0                          3
# 1                      14                 3.0                          1
# 2                      11                 3.0                          4
# 3                      19                 3.0                          2
# 4                      12                 3.0                          4
# ...                   ...                 ...                        ...
# 1608                   12                 3.0                          3
# 1610                   12                 3.0                          2
# 1611                   18                 3.0                          4
# 1612                   13                 3.0                          4
# 1613                   13                 3.0                          2
#
#       stock_option_level  training_times_last_year  work_life_balance  \
# 0                      0                         5                  3
# 1                      1                         5                  3
# 2                      0                         3                  3
# 3                      2                         2                  3
# 4                      1                         5                  3
# ...                  ...                       ...                ...
# 1608                   1                         2                  4
# 1610                   0                         5                  2
# 1611                   0                         3                  3
# 1612                   2                         3                  3
# 1613                   1                         3                  3
#
#       years_at_company  years_since_last_promotion  years_with_curr_manager  \
# 0                   20                          15                       15
# 1                   33                          11                        9
# 2                   22                          11                       15
# 3                   20                           5                        6
# 4                   19                           2                        8
# ...                ...                         ...                      ...
# 1608                 8                           6                        3
# 1610                 9                           0                        8
# 1611                 8                           0                        7
# 1612                 7                           0                        7
# 1613                 8                           0                        7
#
#       date_birth remote_work  hourly_rate  daily_rate  distance_from_home  \
# 0           1972         yes           51       684.0                 6.0
# 1           1971         yes           65       699.0                 1.0
# 2           1981         yes           58       532.0                 4.0
# 3           1976          no           82       359.0                 2.0
# 4           1977          no           45      1319.0                 3.0
# ...          ...         ...          ...         ...                 ...
# 1608        1991         yes           93       498.0                 3.0
# 1610        1978         yes           57       805.0                 4.0
# 1611        1984         yes           41       903.0                10.6
# 1612        1987         yes           84      1229.0                 8.0
# 1613        1977          no           75       566.0                 7.0
#
#       monthly_income  total_working_years     grupo
# 0            19537.0                    6   control
# 1            19999.0                   34   control
# 2            19232.0                   22   control
# 3            17169.0                    5   control
# 4             5361.8                    6  variante
# ...              ...                  ...       ...
# 1608          6725.0                    8  variante
# 1610          4447.0                    8  variante
# 1611          7159.4                    9   control
# 1612          5308.8                   12   control
# 1613         10845.0                    9   control
#
# [1269 rows x 34 columns]

# %%
variante_si=df[variante&si].count()/df[variante].count()*100
variante_si
descontentos_fuera = 19.49
descontentos_diferencia = 80.51-19.49
descontentos_diferencia
# Out:
# 61.02000000000001

# %%
variante_no=df[variante&no].count()/df[variante].count()*100
variante_no
descontentos_dentro = 80.51

# %%
tabla_contingencia_grafica= pd.crosstab(df['grupo'], df['attrition']).reset_index()

# %%
contingency_table = pd.crosstab(df['grupo'], df['attrition'])
contingency_table
# Out:
# attrition   No  Yes
# grupo
# control    798  127
# variante   471  114

# %%
chi2, p_chi2, _, _ = stats.chi2_contingency(contingency_table)
print(f"Prueba de Chi-cuadrado - p-valor: {p_chi2}")
# Out:
# Prueba de Chi-cuadrado - p-valor: 0.0036860670797145547

# %%
# hacemos un análisis visual previo
fig, axes = plt.subplots(nrows = 1, ncols = 2, figsize = (20, 5))
sns.barplot(x="grupo", y="Yes", data=tabla_contingencia_grafica,  palette = "flare", ax = axes[0])
sns.barplot(x="grupo", y="No", data=tabla_contingencia_grafica,  palette = "flare", ax = axes[1])
axes[0].set_title("Han dejado la empresa", fontsize=15)
axes[1].set_title("Siguen en la empresa", fontsize=15)
axes[0].set_xlabel('Grupos de satisfacción')
axes[0].set_ylabel('Número de empleados')
axes[1].set_xlabel('Grupos de satisfacción')
axes[1].set_ylabel('Número de empleados');

# %%
# Realizar la prueba de proporciones
chi2, p_value, _, _ = stats.chi2_contingency(contingency_table)
# Imprimir el resultado de la prueba
alpha = 0.05
if p_value < alpha:
    print("Hay una diferencia significativa entre la gente que ha dejado la empresa entre el grupo control y el grupo variante.")
    print("\n ---------- \n")
    
else:
    print("No hay evidencia de una diferencia significativa entre la gente que ha dejado la empresa entre el grupo control y el grupo variante.")
    print("\n ---------- \n")
# Out:
# Hay una diferencia significativa entre la gente que ha dejado la empresa entre el grupo control y el grupo variante.
#
#  ----------

# %%
df["monthly_income"].describe().T
# Out:
# count     1510.000000
# mean      6201.509272
# std       3627.729599
# min       1009.000000
# 25%       3902.500000
# 50%       5368.000000
# 75%       7260.200000
# max      19999.000000
# Name: monthly_income, dtype: float64

# %%
df['salario'] = np.where(df['monthly_income']>=5500, 'alto', 'bajo')

# %%
tabla_contingencia_grafica2= pd.crosstab(df['salario'], df['attrition']).reset_index()

# %%
contingency_table2 = pd.crosstab(df['salario'], df['attrition'])
contingency_table2
# Out:
# attrition   No  Yes
# salario
# alto       635   81
# bajo       634  160

# %%
(81/(635+81))*100
# Out:
# 11.312849162011174

# %%
(160/(634+160))*100
# Out:
# 20.151133501259448

# %%
#Realizar la prueba de proporciones
chi2, p_value, _, _ = stats.chi2_contingency(contingency_table2)
# Imprimir el resultado de la prueba
alpha = 0.05
if p_value < alpha:
    print("Hay una diferencia significativa entre la gente que ha dejado la empresa entre el grupo con salario más alto y el grupo con salario más bajo.")
    print("\n ---------- \n")
    
else:
    print("No hay evidencia de una diferencia significativa entre la gente que ha dejado la empresa entre el grupo con salario más alto y el grupo con salario más bajo.")
    print("\n ---------- \n")
# Out:
# Hay una diferencia significativa entre la gente que ha dejado la empresa entre el grupo con salario más alto y el grupo con salario más bajo.
#
#  ----------

# %%
# hacemos un análisis visual previo
fig, axes = plt.subplots(nrows = 1, ncols = 2, figsize = (20, 5))
sns.barplot(x="salario", y="Yes", data=tabla_contingencia_grafica2,  palette = "flare", ax = axes[0])
sns.barplot(x="salario", y="No", data=tabla_contingencia_grafica2,  palette = "flare", ax = axes[1])
axes[0].set_title("Han dejado la empresa", fontsize=15)
axes[1].set_title("Siguen en la empresa", fontsize=15)
axes[0].set_xlabel('Nivel salarial')
axes[0].set_ylabel('Número de empleados')
axes[1].set_xlabel('Nivel salarial')
axes[1].set_ylabel('Número de empleados');

# %%
df["distance_from_home"].describe().T
# Out:
# count    1510.000000
# mean        9.057351
# std         7.565011
# min         1.000000
# 25%         2.000000
# 50%         7.200000
# 75%        13.000000
# max        29.000000
# Name: distance_from_home, dtype: float64

# %%
df['distancia_casa'] = np.where(df['distance_from_home']>=8, 'alta', 'baja')

# %%
tabla_contingencia_grafica3= pd.crosstab(df['distancia_casa'], df['attrition']).reset_index()

# %%
contingency_table3 = pd.crosstab(df['distancia_casa'], df['attrition'])
contingency_table3
# Out:
# attrition        No  Yes
# distancia_casa
# alta            615  129
# baja            654  112

# %%
# hacemos un análisis visual previo
fig, axes = plt.subplots(nrows = 1, ncols = 2, figsize = (20, 5))
sns.barplot(x='distancia_casa', y="Yes", data=tabla_contingencia_grafica3,  palette = "flare", ax = axes[0])
sns.barplot(x='distancia_casa', y="No", data=tabla_contingencia_grafica3,  palette = "flare", ax = axes[1])
axes[0].set_title("Han dejado la empresa", fontsize=15)
axes[1].set_title("Siguen en la empresa", fontsize=15)
axes[0].set_xlabel('Distancia a casa')
axes[0].set_ylabel('Número de empleados')
axes[1].set_xlabel('Distancia a casa')
axes[1].set_ylabel('Número de empleados');

# %%
#Realizar la prueba de proporciones
chi2, p_value, _, _ = stats.chi2_contingency(contingency_table3)
# Imprimir el resultado de la prueba
alpha = 0.05
if p_value < alpha:
    print("Hay una diferencia significativa entre la gente que ha dejado la empresa entre el grupo con salario más alto y el grupo con salario más bajo.")
    print("\n ---------- \n")
    
else:
    print("No hay evidencia de una diferencia significativa entre la gente que ha dejado la empresa entre el grupo con salario más alto y el grupo con salario más bajo.")
    print("\n ---------- \n")
# Out:
# No hay evidencia de una diferencia significativa entre la gente que ha dejado la empresa entre el grupo con salario más alto y el grupo con salario más bajo.
#
#  ----------
