# %%
# Importar librerías para tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd  # Pandas es una poderosa librería para manipulación y análisis de datos en Python.

# Importar librerías para web scraping y manipulación de datos
# -----------------------------------------------------------------------
from bs4 import BeautifulSoup
import requests

# Importar librerías para automatización de navegadores web con Selenium
# -----------------------------------------------------------------------
from selenium import webdriver  # Selenium es una herramienta para automatizar la interacción con navegadores web.
from webdriver_manager.chrome import ChromeDriverManager  # ChromeDriverManager gestiona la instalación del controlador de Chrome.
from selenium.webdriver.common.keys import Keys  # Keys es útil para simular eventos de teclado en Selenium.
from selenium.webdriver.support.ui import Select  # Select se utiliza para interactuar con elementos <select> en páginas web.

# Importar librerías para pausar la ejecución
# -----------------------------------------------------------------------
from time import sleep  # Sleep se utiliza para pausar la ejecución del programa por un número de segundos.

# Configuraciones
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None)  # Establece una opción de Pandas para mostrar todas las columnas de un DataFrame.

# %%
driver = webdriver.Chrome()
driver.get("https://www.casadellibro.com")
sleep(2)
#maximizar
driver.maximize_window()
sleep(2)
#aceptar cookies
driver.find_element("css selector", "#onetrust-accept-btn-handler").click()
sleep(2)
driver.find_element("link text", 'Ficción').click()
sleep(2)
libro ={"titulo": [],
         "autor":[],
         "precio":[],
         "editorial":[],
         "idioma":[],
         "paginas":[]}
sleep(2)
#iterar por productos 1 al 5
for i in range (1,6):
#driver.find_element("xpath", '//*[@id="buscadorNF"]/div[3]/div/div[3]/div[1]/a/div/img').click()
    sleep(3)
    driver.find_element("css selector", f'#buscadorNF > div.col-md-9.col-12 > div > div.grid-view.mt-4 > div:nth-child({i}) > a > div > img').click()
    sleep(3)
    libro ["titulo"].append(driver.find_element("xpath",'//*[@id="app"]/div[1]/main/div/div/div/div[3]/div/div[2]/div/h1').text)
    libro ["autor"].append(driver.find_element("xpath",'//*[@id="app"]/div[1]/main/div/div/div/div[3]/div/div[2]/div/div[2]/div/a/span[1]').text)
    libro ["precio"].append(driver.find_element("xpath",'//*[@id="app"]/div[1]/main/div/div/div/div[3]/div/div[3]/div/div[3]/div[1]/strong').text)
    libro ["editorial"].append(driver.find_element("xpath",'//*[@id="app"]/div[1]/main/div/div/div/div[3]/div/div[2]/div/div[4]/div[1]/span[1]').text)
    try:
        libro ["idioma"].append(driver.find_element("xpath",'//*[@id="app"]/div[1]/main/div/div/div/div[7]/div/div[2]/div/div[3]/div[2]/span').text)
    except:
        libro ["idioma"].append(driver.find_element("xpath",'//*[@id="app"]/div[1]/main/div/div/div/div[8]/div/div[2]/div/div[3]/div[2]/span').text)
    try:
        libro ["paginas"].append(driver.find_element("xpath",'//*[@id="app"]/div[1]/main/div/div/div/div[7]/div/div[2]/div/div[1]/div[2]/span').text)
    except:
        libro ["paginas"].append(driver.find_element("xpath",'//*[@id="app"]/div[1]/main/div/div/div/div[8]/div/div[2]/div/div[1]/div[2]/span').text)
    sleep(2)
    driver.back()
libro
# Out:
# {'titulo': ['LA CHICA DEL VERANO (NOVELA)',
#   'LA ARMADURA DE LA LUZ (SAGA LOS PILARES DE LA TIERRA 5)',
#   'EL INFIERNO',
#   'EL PROBLEMA FINAL',
#   'TODO VUELVE (SERIE TODO ARDE 2)'],
#  'autor': ['LA VECINA RUBIA',
#   'KEN FOLLETT',
#   'CARMEN MOLA',
#   'ARTURO PEREZ REVERTE',
#   'JUAN GOMEZ JURADO'],
#  'precio': ['18,90 €', '23,65 €', '21,75 €', '20,80 €', '21,75 €'],
#  'editorial': ['TIMUN MAS',
#   'PLAZA & JANES EDITORES',
#   'PLANETA',
#   'ALFAGUARA',
#   'EDICIONES B'],
#  'idioma': ['CASTELLANO',
#   'CASTELLANO',
#   'CASTELLANO',
#   'CASTELLANO',
#   'CASTELLANO'],
#  'paginas': ['424', '832', '480', '328', '608']}

# %%
tabla_libros = pd.DataFrame(libro)
tabla_libros
# Out:
#                                               titulo                 autor  \
# 0                       LA CHICA DEL VERANO (NOVELA)       LA VECINA RUBIA
# 1  LA ARMADURA DE LA LUZ (SAGA LOS PILARES DE LA ...           KEN FOLLETT
# 2                                        EL INFIERNO           CARMEN MOLA
# 3                                  EL PROBLEMA FINAL  ARTURO PEREZ REVERTE
# 4                    TODO VUELVE (SERIE TODO ARDE 2)     JUAN GOMEZ JURADO
#
#     precio               editorial      idioma paginas
# 0  18,90 €               TIMUN MAS  CASTELLANO     424
# 1  23,65 €  PLAZA & JANES EDITORES  CASTELLANO     832
# 2  21,75 €                 PLANETA  CASTELLANO     480
# 3  20,80 €               ALFAGUARA  CASTELLANO     328
# 4  21,75 €             EDICIONES B  CASTELLANO     608
