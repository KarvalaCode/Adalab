# %% [markdown]
# # Pair programming Beautiful Soup
#
# Enunciado: Escribe una función llamada scrape_coches_ocasion que acepta una URL como argumento y devuelve un DataFrame de pandas con información sobre coches de ocasión encontrados en la página web especificada. La función realizará las siguientes tareas:
#
# 1. Realizará una solicitud HTTP GET a la url siguiente: https://www.ocasionplus.com/coches-ocasion?type%3DCAR%26sort%3DFECHAOP_DESC%26page%3D2
#
# 2. Comprobará el código de estado de la respuesta. Si el código no es 200 (OK), imprimirá un mensaje de error y retornará None.

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re

url_coches = 'https://www.ocasionplus.com/coches-ocasion?type%3DCAR%26sort%3DFECHAOP_DESC%26page%3D2'

res_coches = requests.get(url_coches)
res_coches.status_code
# Out:
# 200

# %%
sopa_coches = BeautifulSoup(res_coches.content, 'html.parser')
sopa_coches
# Out:
# <!DOCTYPE html>
# <html><head><meta charset="utf-8" class="next-head"/><title class="next-head">Coches de segunda mano, ocasión y seminuevos | OcasionPlus</title><meta class="next-head" content="4000 coches de ocasión y segunda mano con descuentos de hasta 6000€, la mejor relación calidad-precio garantizada." name="description"/><meta class="next-head" content="noindex, follow, noarchive" name="robots"/><meta class="next-head" content="width=device-width, initial-scale=1.0" name="viewport"/><link class="next-head" href="/static/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/><link class="next-head" href="/static/favicon/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/><link class="next-head" href="/static/favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/><link class="next-head" href="/static/favicon/favicon-194x194.png" rel="icon" sizes="194x194" type="image/png"/><link class="next-head" href="/static/favicon/android-chrome-192x192.png" rel="icon" sizes="192x192" type="image/png"/><link class="next-head" href="/static/favicon/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/><link class="next-head" href="/static/site.webmanifest" rel="manifest"/><link class="next-head" color="#5bbad5" href="/static/favicon/safari-pinned-tab.svg" rel="mask-icon"/><meta class="next-head" content="OcasionPlus" name="apple-mobile-web-app-title"/><meta class="next-head" content="OcasionPlus" name="application-name"/><meta class="next-head" content="/static/browserconfig.xml" name="msapplication-config"/><meta class="next-head" content="#2d89ef" name="msapplication-TileColor"/><meta class="next-head" content="/static/favicon/mstile-144x144.png" name="msapplication-TileImage"/><meta class="next-head" content="#ffffff" name="theme-color"/><meta class="next-head" content="website" property="og:type"/><meta class="next-head" content="" property="og:url"/><meta class="next-head" content="Coches de segunda mano, ocasión y seminuevos" property="og:title"/><meta class="next-head" content="4000 coches de ocasión y segunda mano con descuentos de hasta 6000€, la mejor relación calidad-precio garantizada." property="og:description"/><meta class="next-head" content="" name="twitter:site"/><meta class="next-head" content="summary_large_image" name="twitter:card"/><meta class="next-head" content="" name="twitter:image"/><meta class="next-head" content="" property="og:image"/><meta class="next-head" content="1200" property="og:image:width"/><meta class="next-head" content="630" property="og:image:height"/><link class="next-head" href="/assets/css/styles.min.css" media="screen" rel="stylesheet" type="text/css"/><link class="next-head" href="/assets/css/styles.header.css" media="screen" rel="stylesheet" type="text/css"/><link class="next-head" href="//cdnjs.cloudflare.com/ajax/libs/semantic-ui/2.2.12/semantic.min.css" rel="stylesheet" type="text/css"/><link class="next-head" href="//cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css" rel="stylesheet" type="text/css"/><link class="next-head" href="//cdnjs.cloudflare.com/ajax/libs/react-select/1.2.1/react-select.min.css" rel="stylesheet" type="text/css"/><link class="next-head" href="//cdnjs.cloudflare.com/ajax/libs/slick-carousel/1.8.1/slick.min.css" rel="stylesheet" type="text/css"/><link class="next-head" href="//cdnjs.cloudflare.com/ajax/libs/slick-carousel/1.8.1/slick-theme.min.css" rel="stylesheet" type="text/css"/><link class="next-head" href="/static/global.css" rel="stylesheet" type="text/css"/><link class="next-head" href="/assets/css/styles.local.css" media="screen" rel="stylesheet" type="text/css"/><link class="next-head" href="https://www.ocasionplus.com/coches-ocasion" rel="canonical"/><script class="next-head" type="application/ld+json">{"@context":"https://schema.org","@graph":[{"@type":"Organization","@id":"https://www.ocasionplus.com/#organization","name":"OcasionPlus","url":"https://www.ocasionplus.com/","contactPoint":[{"@type":"Contac ...
#                                 (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#                                 new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#                                 j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#                                 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#                                 })(window,document,'script','dataLayer','GTM-5WCK7B');
#                               </script></head><body><noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-5WCK7B" style="display:none;visibility:hidden" width="0"></iframe></noscript><div id="__next"><nav class="op-header" id="topIdToScroll"><div class="c-container--fluid p-0"><nav class="" id="topIdToScroll" role="header"><div class="TelephoneAttentionButton__container"><svg fill="#333" height="30" id="i-phone-border" stroke="none" stroke-linecap="round" stroke-linejoin="round" stroke-width="6.25%" viewbox="0 0 26 26" width="30" xmlns="http://www.w3.org/2000/svg"><path d="M9.41333 12.1933C10.3733 14.08 11.92 15.6267 13.8067 16.5867L15.2733 15.12C15.46 14.9333 15.72 14.88 15.9533 14.9533C16.7 15.2 17.5 15.3333 18.3333 15.3333C18.5101 15.3333 18.6797 15.4036 18.8047 15.5286C18.9298 15.6536 19 15.8232 19 16V18.3333C19 18.5101 18.9298 18.6797 18.8047 18.8047C18.6797 18.9298 18.5101 19 18.3333 19C15.3275 19 12.4449 17.806 10.3195 15.6805C8.19404 13.5551 7 10.6725 7 7.66667C7 7.48986 7.07024 7.32029 7.19526 7.19526C7.32029 7.07024 7.48986 7 7.66667 7H10C10.1768 7 10.3464 7.07024 10.4714 7.19526C10.5964 7.32029 10.6667 7.48986 10.6667 7.66667C10.6667 8.5 10.8 9.3 11.0467 10.0467C11.12 10.28 11.0667 10.54 10.88 10.7267L9.41333 12.1933Z" fill="#333" fill-opacity="0.87"></path><path clip-rule="evenodd" d="M0.5 13C0.5 6.09644 6.09644 0.5 13 0.5C19.9036 0.5 25.5 6.09644 25.5 13C25.5 19.9036 19.9036 25.5 13 25.5C6.09644 25.5 0.5 19.9036 0.5 13ZM13 1.5C6.64873 1.5 1.5 6.64873 1.5 13C1.5 19.3513 6.64873 24.5 13 24.5C19.3513 24.5 24.5 19.3513 24.5 13C24.5 6.64873 19.3513 1.5 13 1.5Z" fill="#333" fill-opacity="0.87" fill-rule="evenodd"></path></svg><div class="TelephoneAttentionButton__content"><span class="TelephoneAttentionButton__mainText">Hora de atención telefónica</span><span class="TelephoneAttentionButton__secondaryText">Lun a Sáb: 9:00 a 21:00, Dom: 10:00 a 21:00</span></div></div><div class="SliderPanel__container SliderPanel__hide SliderPanel__grey" role="slider-panel"><button class="IconClose__container IconClose__grey" type="button"><svg fill="none" height="20" id="i-close" stroke="currentcolor" stroke-linecap="round" stroke-linejoin="round" stroke-width="3%" viewbox="0 0 32 32" width="20"><path d="M2 30 L30 2 M30 30 L2 2"></path></svg></button><div class="MenuPanelSlider__content"><ul class="MenuPanelSlider__container"><li class="ItemsList__link-menu-slider ItemsList__border ItemsList__hover-lightgrey ItemsList__isHover"><a class="Link__link-menu-slider Link__grey" href="/coches-ocasion" rel="noopener" style="font-weight:600;justify-content:center" target="_self" title="Comprar coche">COMPRAR COCHE</a></li><li class="ItemsList__link-menu-slider ItemsList__border ItemsList__hover-lightgrey" style="background-color:gold"><a class="Link__link-menu-slider Link__grey" href="/ofertas-especiales" rel="noopener" style="font-weight:600;justify-content:center" target="_self" title="Coches con Descuento">Coches con descuento</a></li><li class="ItemsList__link-menu-slider ItemsList__border ItemsList__hover-lightgrey ItemsList__isHover"><a class="Link__link-menu-slider Link__grey" href="/vender-mi-coche" rel="noopener" style="font-weight:600;justify-content:center" target="_self" title="Vender mi coche">VENDER MI COCHE</a></li><li class="ItemsList__link-menu-slider ItemsList__border ItemsList__hover-lightgrey ItemsList__isHover"><a class="Link__link-menu-slider Link__grey" href="/motos-ocasion" rel="noopener" style="font-weight:600;justify-content:center" target="_self" title="Comprar Moto">COMPRAR MOTO</a></li><li class="ItemsList__link-menu-slider ItemsList__border ItemsList__hover-lightgrey ItemsList__isHover"><a class="Link__link-menu-slider Link__grey" href="/vender-mi-moto" rel="noopener" style="font-weight:600;justify-content:center" target="_self" title="Vender mi moto">VENDER MI MOTO</a></li><li class="ItemsList__link-menu-slider ItemsList__border ItemsList__hover-lightgrey ItemsList__isHover"><a class="L ...
#           __NEXT_DATA__ = {"props":{"isServer":true,"store":{"sagaTask":{"@@redux-saga/TASK":true,"id":6274,"name":"rootSaga","joiners":null,"done":{}}},"initialState":{"searchParams":{"type":{"label":"Tipo: Coche","value":{"key":"CAR","value":"CAR","label":"Coche"}},"region":{"label":null},"location":{"label":null},"sort":{"label":"Los más populares","value":"FECHAOP_DESC","name":"Ordenado por:"},"url":{"basePath":"https://www.ocasionplus.com/coches-ocasion","query":"?type%3DCAR%26sort%3DFECHAOP_DESC%26page%3D2"},"page":{"label":"","value":2},"valueDTL":"coche+2"},"searchResults":{"vehicleCount":false,"showMessageNoFound":{}},"form":{},"routerParams":{"cookies":false,"utms":{},"totalPages":1,"params":{"type=CAR\u0026sort=FECHAOP_DESC\u0026page=2":""},"path":"/coches-ocasion"},"tasacion":{"tasacion_ready":false,"final_action_ready":false,"error":false},"tasacionCoche":{"error":false,"isLoading":false,"fetchedResults":{},"userData":{},"fetchableKeys":["tipo","fecha_hasta","marca","modelo","puertas","combustible","carroceria","version"]},"car":{},"configuration":{"oplusLocations":[{"id":"5d4997e87f484543210adc0e","name_key":"OPLUS_ALBACETE","motorflashKey":"Ocasionplus - Albacete","name":"Albacete","short_name":"Albacete","slug":"albacete","color":{"bg":"#C44D58","alt":"#FFF"},"address":"Polígono Industrial Campollano, Avenida Adeca 2 (Frente al Palacio de Congresos)","city":"Albacete","cp":"02007","state":"Albacete","region":"Castilla-La Mancha","noWarrantyPhone":"967 264 956","tel":"967 880 701","types":["SHOP","TALLER","TASACION"],"location_key":"ALBACETE","whatsapp":{"name":"whatsapp","tel":"663695693"},"mail":"comercialalbacete@ocasionplus.com","position":{"lat":39.0143503,"lng":-1.873343},"notes":"","gmaps_places":"https://www.google.com/maps/place/OcasionPlus+Albacete/@39.0147158,-1.8732324,17z/data=!4m12!1m6!3m5!1s0xd665fa3b295588b:0xd7fc15e1b5666bf3!2sOcasionPlus+Albacete!8m2!3d39.0143503!4d-1.873343!3m4!1s0xd665fa3b295588b:0xd7fc15e1b5666bf3!8m2!3d39.0143503!4d-1.873343","horario":{"laboral":[{"from":"09:30","to":"20:30"}],"saturdays":[{"from":"10:00","to":"14:00"},{"from":"17:00","to":"20:30"}],"sundays":[],"holidays":[],"specialDays":[{"title":"FESTIVO","date":{"from":"2023-09-08T00:00:00.000Z","to":null},"notificationDays":200,"schedule":[{"from":"10:00","to":"14:00","isClosed":false},{"from":"17:00","to":"20:30","isClosed":false}]},{"title":"Festivo","date":{"from":"2023-05-31T00:00:00.000Z","to":"2023-05-31T00:00:00.000Z"},"notificationDays":200,"schedule":[{"from":"10:00","to":"14:00","isClosed":false},{"from":"17:00","to":"20:30","isClosed":false}]},{"title":"Dia del trabajador","date":{"from":"2023-05-01T00:00:00.000Z","to":"2023-05-01T00:00:00.000Z"},"notificationDays":200,"schedule":[{"from":"10:00","to":"14:00","isClosed":false}]},{"title":"SEMANA SANTA","date":{"from":"2023-04-06T00:00:00.000Z","to":"2023-04-07T00:00:00.000Z"},"notificationDays":200,"schedule":[{"from":"10:00","to":"14:00","isClosed":false}]},{"title":"Domingo - Gran Feria de OcasionPlus","date":{"from":"2021-06-20T00:00:00.000Z","to":null},"notificationDays":200,"schedule":[{"from":"10:00","to":"14:00","isClosed":false}]},{"title":"Domingo - Gran Feria de OcasionPlus","date":{"from":"2021-06-27T00:00:00.000Z","to":null},"notificationDays":200,"schedule":[{"from":"10:00","to":"14:00","isClosed":false}]},{"title":"Fiesta de San Juan","date":{"from":"2022-06-24T00:00:00.000Z","to":null},"notificationDays":100,"schedule":[{"from":"10:00","to":"14:00","isClosed":false}]},{"title":"Fiesta de la Hispanidad","date":{"from":"2021-10-12T00:00:00.000Z","to":null},"notificationDays":200,"schedule":[{"from":"10:00","to":"14:00","isClosed":false}]},{"title":"Todos los Santos","date":{"from":"2021-11-01T00:00:00.000Z","to":null},"notificationDays":200,"schedule":[{"from":"10:00","to":"14:00","isClosed":false}]},{"title":"Día de la Constitución Española","date":{"from":"2021-12-06T00:00:00.000Z","to":null},"notificationDays":200,"schedule":[{"from":"10:00 ...
#           module={}
#           __NEXT_LOADED_PAGES__ = []
#           __NEXT_LOADED_CHUNKS__ = []
#
#           __NEXT_REGISTER_PAGE = function (route, fn) {
#             __NEXT_LOADED_PAGES__.push({ route: route, fn: fn })
#           }
#
#           __NEXT_REGISTER_CHUNK = function (chunkName, fn) {
#             __NEXT_LOADED_CHUNKS__.push({ chunkName: chunkName, fn: fn })
#           }
#
#           false
#         </script><script async="" id="__NEXT_PAGE__/search-all" src="/_next/4fffadd6-330a-4ab6-9cc8-93741fffc828/page/search-all.js"></script><script async="" id="__NEXT_PAGE__/_error" src="/_next/4fffadd6-330a-4ab6-9cc8-93741fffc828/page/_error.js"></script><script async="" src="/_next/4fffadd6-330a-4ab6-9cc8-93741fffc828/main.js"></script></body></html>

# %% [markdown]
# 3. Extraerá los nombres de los coches, los precios rebajados, los precios originales y la información de los kilómetros recorridos de la página.

# %%
#nombres de los coches
lista_nombre_coches = sopa_coches.find_all('h2', {'style':"overflow-x:hidden"})
lista_nombre_coches
nombre_coches = []
for coche in lista_nombre_coches:
    nombre_coches.append(coche.text)
nombre_coches
# Out:
# ['Skoda Kamiq 1.0 TSI Ambition  (110 CV)',
#  'Peugeot 2008 SUV SUV BlueHDi 100 Signature (100 CV)',
#  'Mercedes-Benz Clase CLA Shooting Brake (122 CV)',
#  'Renault Grand Scenic Limited Blue dCi (120 CV) 7 PLAZAS',
#  'BMW Serie 5 BMW Serie 5 520d Touring 140 kW (190 CV',
#  'Kia Stonic 1.0 T-GDi Eco-Dynamic Drive (120 CV)',
#  'Mercedes-Benz Clase GLB MERCEDES GLB 2.0 200 D DCT (150CV) PAQUETE AMG',
#  'Fiat 500X 1.3 MultiJet Mirror 4x2 (95 CV)',
#  'Chevrolet Cruze 2.0 VCDI LS  (125 CV)',
#  'SEAT Arona 1.0 TSI (115CV) FR Ecomotive',
#  'Honda Civic 1.4 I-VTEC Comfort (100 CV)',
#  'Toyota Yaris 1.0 City (69 CV)',
#  'Citroen C3 PureTech 82 Feel (83 CV)',
#  'SEAT Ibiza S&S Reference Plus (80 CV)',
#  'Peugeot 308 SW SW BlueHDi 130 S&S Active Pack  (130 CV)',
#  'Nissan X-Trail 2.0 dCi N-Connecta 4x2 XTronic Auto (177 CV)',
#  'Citroen C5 Aircross 30 S&S Shine (131 CV)',
#  'Ford Focus 1.6 TDCI Trend  (115 CV)',
#  'Citroen C3 Aircross PureTech 110 S&S Feel (110 CV)',
#  'Kia Soul 1.6 CRDi Concept Eco-Dynamics (136 CV)']

# %%
#los precios rebajados
lista_precio_r_coches = sopa_coches.find_all('span', {'class':"jsx-2689423372 price"})

precio_r_coches = []
for precio in lista_precio_r_coches:
    precio_r_coches.append(precio.text)
precio_r_coches
# Out:
# ['20.818€',
#  '12.909€',
#  '28.000€',
#  '21.727€',
#  '30.818€',
#  '15.318€',
#  '39.000€',
#  '14.136€',
#  '5.300€',
#  '15.445€',
#  '12.990€',
#  '10.227€',
#  '8.627€',
#  '11.727€',
#  '14.364€',
#  '21.682€',
#  '19.773€',
#  '7.200€',
#  '12.545€',
#  '12.545€']

# %%
# los precios originales {'class':"jsx-2689423372 price"}
lista_precio_o_coches = sopa_coches.find_all('span', {'class' : "jsx-2870186023 priceLast"})
lista_precio_o_coches
precio_o_coches = []
for precio in lista_precio_o_coches:
    precio_o_coches.append(precio.text)
precio_o_coches
# Out:
# ['22.900€',
#  '14.200€',
#  '30.800€',
#  '23.900€',
#  '33.900€',
#  '16.850€',
#  '42.900€',
#  '15.550€',
#  '16.990€',
#  '11.250€',
#  '9.490€',
#  '12.900€',
#  '15.800€',
#  '23.850€',
#  '21.750€',
#  '13.800€',
#  '13.800€']

# %%
#información de los kilómetros
lista_km_coches = sopa_coches.find_all('span', {'class' : "jsx-3960002075 detail big"})
km_coches = []
for km in lista_km_coches:    
    km_coches.append(km.text)
km_coches
# Out:
# ['01/2023',
#  '11.151 km',
#  'Gasolina',
#  'Manual',
#  'Garantía oficial: Febrero 2025',
#  '07/2019',
#  '52.846 km',
#  'Diésel',
#  'Manual',
#  'Libro Mantenimiento',
#  'Único propietario',
#  '02/2019',
#  '56.126 km',
#  'Gasolina',
#  'Automático',
#  'Único propietario',
#  '09/2019',
#  '60.828 km',
#  'Diésel',
#  'Manual',
#  '03/2021',
#  '68.564 km',
#  'Híbrido',
#  'Automático',
#  'Libro Mantenimiento',
#  'Único propietario',
#  '03/2018',
#  '36.395 km',
#  'Gasolina',
#  'Manual',
#  'Único propietario',
#  'Garantía oficial: Abril 2025',
#  '02/2021',
#  '58.565 km',
#  'Diésel',
#  'Automático',
#  'Libro Mantenimiento',
#  'Único propietario',
#  '08/2018',
#  '80.787 km',
#  'Diésel',
#  'Manual',
#  '02/2010',
#  '162.006 km',
#  'Diésel',
#  'Manual',
#  'Libro Mantenimiento',
#  'Único propietario',
#  '09/2019',
#  '48.954 km',
#  'Gasolina',
#  'Manual',
#  '06/2013',
#  '97.531 km',
#  'Gasolina',
#  'Manual',
#  'Libro Mantenimiento',
#  '07/2017',
#  '53.529 km',
#  'Gasolina',
#  'Manual',
#  'Libro Mantenimiento',
#  '05/2017',
#  '128.270 km',
#  'Gasolina',
#  'Manual',
#  'Libro Mantenimiento',
#  '05/2019',
#  '25.304 km',
#  'Gasolina',
#  'Manual',
#  'Libro Mantenimiento',
#  'Único propietario',
#  '03/2021',
#  '85.643 km',
#  'Diésel',
#  'Manual',
#  '10/2018',
#  '97.343 km',
#  'Diésel',
#  'Automático',
#  'Libro Mantenimiento',
#  'Único propietario',
#  '10/2019',
#  '44.866 km',
#  'Gasolina',
#  'Manual',
#  '10/2011',
#  '145.688 km',
#  'Diésel',
#  'Manual',
#  'Libro Mantenimiento',
#  '01/2020',
#  '62.524 km',
#  'Gasolina',
#  'Manual',
#  'Libro Mantenimiento',
#  '04/2017',
#  '73.833 km',
#  'Diésel',
#  'Manual',
#  'Libro Mantenimiento',
#  'Único propietario']

# %%
km_coches_ok = []
for km in km_coches:
    lista_km = re.findall('\d+\.\d+\skm', km)
    if len(lista_km) >= 1:
       km_coches_ok.append(km)

km_coches_ok
# Out:
# ['11.151 km',
#  '52.846 km',
#  '56.126 km',
#  '60.828 km',
#  '68.564 km',
#  '36.395 km',
#  '58.565 km',
#  '80.787 km',
#  '162.006 km',
#  '48.954 km',
#  '97.531 km',
#  '53.529 km',
#  '128.270 km',
#  '25.304 km',
#  '85.643 km',
#  '97.343 km',
#  '44.866 km',
#  '145.688 km',
#  '62.524 km',
#  '73.833 km']

# %%
print('nombres', len(lista_nombre_coches))
print('precio r', len(lista_precio_r_coches))
print('precio o', len(lista_precio_o_coches))
print('km', len(km_coches_ok))
# Out:
# nombres 20
# precio r 20
# precio o 17
# km 20

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re

def scrape_coches_ocasion(url):

    res_coches = requests.get(url)
    print(f"Respuesta: {res_coches.status_code}")
    if res_coches.status_code == 200:
        print("OK")
    else:
        print(f"Error: {res_coches.reason}")
        return None    

    sopa_coches = BeautifulSoup(res_coches.content, 'html.parser')

    #nombres de los coches
    lista_nombre_coches = sopa_coches.find_all('h2', {'style':"overflow-x:hidden"})
    nombre_coches = []
    for coche in lista_nombre_coches:
        nombre_coches.append(coche.text)

    #los precios rebajados
    lista_precio_r_coches = sopa_coches.find_all('span', {'class':"jsx-2689423372 price"})

    precio_r_coches = []
    for precio in lista_precio_r_coches:
        precio_r_coches.append(precio.text)

    # los precios originales {'class':"jsx-2689423372 price"}
    lista_precio_o_coches = sopa_coches.find_all('span', {'class' : "jsx-2870186023 priceLast"})

    precio_o_coches = []
    for precio in lista_precio_o_coches:
        precio_o_coches.append(precio.text)

    #información de los kilómetros
    lista_km_coches = sopa_coches.find_all('span', {'class' : "jsx-3960002075 detail big"})
    km_coches = []
    for km in lista_km_coches:    
        km_coches.append(km.text)

    km_coches_ok = []
    for km in km_coches:
        lista_km = re.findall('\d+\.\d+\skm', km)
        if len(lista_km) >= 1:
            km_coches_ok.append(km)

    diccionario = {"nombre" : [], "precio rebajado": [], "precio original" : [], "km": []}
    lista_elementos = [nombre_coches, precio_r_coches, precio_o_coches, km_coches_ok]

    for indice, valor in enumerate(nombre_coches):
        diccionario["nombre"] = nombre_coches[indice]  
        diccionario["precio rebajado"] = precio_r_coches[indice]  
        diccionario["precio original"] = precio_o_coches[indice]  
        diccionario["km"] = km_coches_ok[indice]  

    df = pd.DataFrame(diccionario)
    
    return df

# %% [markdown]
# 4. Organizará los datos extraídos en un DataFrame de pandas con las siguientes columnas:
# - "coche": Nombres de los coches.
# - "precio_rebajado": Precios rebajados.
# - "precio_original": Precios originales.
# - "km": Kilómetros recorridos.

# %% [markdown]
# 5. Retornará el DataFrame resultante.

# %% [markdown]
# 6. Una vez extraida toda la información deberéis almacenar toda la información en un DataFrame. El DataFrame debe tener un aspecto parecido a este:
# Coche
# Precio Rebajado
# Precio Original
# Kilómetros
# Toyota Corolla 140H Active Plus Auto (140 CV)
# 25.273€
# 27.800€
# 2.839 km
# Ford Focus 1.0 Ecoboost S&S Titanium Auto (125...
# 17.354€
# 19.090€
# 37.479 km
# Hyundai Santa Fe 2.0 CRDI Essence 4x2 7 Plazas...
# 21.363€
# 23.500€
# 51.690 km
# Audi A3 Sportback Sportback 1.6 TDI (116 CV)
# 17.727€
# 19.500€
# 66.918 km
# Hyundai Tucson 1.6 TGDI (177CV) Tecno Sky Safe...
# 23.954€
# 26.350€
# 32.183 km
# Jeep Renegade 1.0G 80 Aniversario 4x2 (120 CV)
# 18.636€
# 20.500€
# 60.279 km
# Renault Captur Zen Energy TCe (120 CV)
# 14.727€
# 16.200€
# 25.316 km
# Audi A1 Sportback 25 TFSI (95 CV)
# 14.363€
# 15.800€
# 65.520 km
# Citroen C4 Cactus PureTech 110 S&S
# 15.082€
# 16.590€
# 35.116 km
# Shine Pack ...
# Kia Sportage GDi Drive 4x2 (132 CV)
# 17.682€
# 20.250€
# 82.460 km
# Dacia Sandero Serie Limitada Xplore TCe (90 CV)
# 12.718€
# 13.990€
# 82.414 km
# SEAT Ateca 1.4 EcoTSI S&S Xcellence (150 CV)
# 21.363€
# 23.500€
# 40.859 km
# Peugeot 208 PEUGEOT 208 PureTech 73kW (100CV) GT
# 17.818€
# 19.600€
# 22.180 km
# Mercedes-Benz Clase CLA CLA 200 (163 CV) PACK AMG
# 30.681€
# 33.750€
# 61.658 km
# Peugeot 208 PureTech 100 GT (100 CV)
# 17.772€
# 19.550€
# 23.631 km
# Opel Astra 1.5 D GS Line (122 CV)
# 14.045€
# 15.450€
# 71.934 km
# SEAT Leon 2.0 TDI S&S Style (115 CV)
# 20.081€
# 22.090€
# 29.035 km
# Peugeot 208 PureTech 100 GT (100 CV)
# 17.681€
# 19.450€
# 30.896 km
# Opel Mokka X OPEL Mokka X 1.4 T 103kW 4X2 Inno...
# 14.727€
# 16.200€
# 114.422 km
# Citroen Berlingo Talla M PureTech 110 S&S SHINE
# 20.818€
# 22.900€
# 49.615 km

# %%
url_coches = 'https://www.ocasionplus.com/coches-ocasion?type%3DCAR%26sort%3DFECHAOP_DESC%26page%3D2'

tabla_coches = scrape_coches_ocasion(url_coches)

tabla_coches
# Out:
# Respuesta: 200
# OK
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1242/2161019232.py in <module>
#       1 url_coches = 'https://www.ocasionplus.com/coches-ocasion?type%3DCAR%26sort%3DFECHAOP_DESC%26page%3D2'
#       2
# ----> 3 tabla_coches = scrape_coches_ocasion(url_coches)
#       4
#       5 tabla_coches
#
# /tmp/ipykernel_1242/2278344943.py in scrape_coches_ocasion(url)
#      54         diccionario["nombre"] = nombre_coches[indice]
#      55         diccionario["precio rebajado"] = precio_r_coches[indice]
# ---> 56         diccionario["precio original"] = precio_o_coches[indice]
#      57         diccionario["km"] = km_coches_ok[indice]
#      58
#
# IndexError: list index out of range
